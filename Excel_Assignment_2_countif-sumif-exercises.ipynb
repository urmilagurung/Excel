# %% [markdown]
# # Excel Assignment 2

# %% [markdown]
# 1. Fill the blank values using countif-sumif

# %% [markdown]
# # Excersise 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Excersise 2

# %% [markdown]
# ![image.png](attachment:image.png)
