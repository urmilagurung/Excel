# %% [markdown]
# # Excel Assignment 9

# %% [markdown]
# 1.	Find the maximum and minimum and sum of all the radiation amounts.

# %%
MINIMUM FORMULA:
    
=MIN(A2:A41)


MAX FORMULA:
    
=MAX(A2:A41)


SUM FORMULA:
    
=SUM(A2:A41)

# %% [markdown]
# 2.	radiation amount

# %%
=SUMPRODUCT((A2:A41<>"")/COUNTIF(A2:A41,A2:A41&""))

# %% [markdown]
# 3.	Find the count and Rank

# %%
COUNT FORMULA:
    
=COUNT(A2:A41)


RANK FORMULA:

=RANK.EQ($A2,$A$2:$A$41,0)

# %% [markdown]
# 4.	Compute the mean and standard deviation of the radiation amounts.

# %%
MEAN FORMULA:

=AVERAGE(A2:A41)    


STANDARD DEVIATION:

=STDEV.P(A2:A41)

# %% [markdown]
# 5.	Describe a certain objective a researcher might have had in mind when collecting this data.

# %% [markdown]
# Researcher measured the radiation of
#
#     1. different places in a country
#     2. different countries
#     3. same location at different time interval
#
# in order to observe or study the factors impacting/effecting the radiation level.

# %% [markdown]
# ![image.png](attachment:image.png)
