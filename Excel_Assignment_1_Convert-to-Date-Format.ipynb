# %% [markdown]
# # Excel Assignment 1

# %% [markdown]
# 1.	Convert to Date Format (Convert-to-Date-Format.xlsx)
#
# This time, you have been given a file containing Text dates into various formats. The challenge before you is to write a single formula to convert them into an appropriate date format.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For this exercise we will use the DATE function.
#
# DATE (year,month,day)
#
# DATE function requires 3 arguments DAY, MONTH, YEAR and each of these has to be a number rather than text.
#
# The month, year and date is the same in all cells. Month = January = 1; Year = 2017 and Day = 2nd
#
# Once we enter the value in the first cell. Click on the cell and double click at the right down corner of the cell to automatically fill the rest of the column.

# %% [markdown]
# RESULT:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# FORMULA USED:
#
# DATE(IF(RIGHT(A1,4)="2017",RIGHT(A1,4),RIGHT(A1,2)+100),VLOOKUP(IF(FIND("Jan",A1,1)<=3,IF(FIND("Jan",A1,1)=1,LEFT(A1,3),MID(A1,3,3)),IF(FIND("Jan",A1,3)=4,MID(A1,4,3),MID(A1,5,3))), {"Jan",1;"Feb",2;"Mar",3;"Apr",4;"May",5;"Jun",6;"Jul",7;"Aug",8;"Sep",9;"Oct",10;"Nov",11;"Dec",12},2,0),IF(ISNUMBER(FIND("2,",A1,1)),IF(ISNUMBER(FIND("02,",A1,1)),IF(ISNUMBER(FIND("Jan 02,",A1,1)),MID(A1,5,2),LEFT(A1,2)),IF(ISNUMBER(FIND("Jan 2,",A1,1)),MID(A1,5,1),LEFT(A1,1))),IF(ISNUMBER(FIND("02",A1,1)),IF(ISNUMBER(FIND("Jan 02",A1,1)),MID(A1,5,2),LEFT(A1,2)),IF(ISNUMBER(FIND("2 Jan",A1,1)),LEFT(A1,1),MID(A1,5,1)))))
